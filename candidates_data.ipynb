# %%
import csv
import os
import pandas as pd
path = r"C:\Users\01est\OneDrive\Documents\learning\govtracker\candidates.csv"

# %%
candidates_df = pd.read_csv(path)

# %%
candidates_df = data.loc[:, ~data.columns.str.contains('^Unnamed')]

# %%
candidates_df
# Out:
#                  name                                  position  \
# 0           Kari Lake                                  Governor
# 1         Katie Hobbs                                  Governor
# 2       Adrian Fontes                        Secretary of State
# 3        Mark Finchem                        Secretary of State
# 4     Abraham Hamadeh                          Attorney General
# ..                ...                                       ...
# 161      Jim Pederson  Central Arizona Water Conservation Dist.
# 162      Karen Peters  Central Arizona Water Conservation Dist.
# 163   Lisa Bullington  Central Arizona Water Conservation Dist.
# 164  Shelby Duplessis  Central Arizona Water Conservation Dist.
# 165    Ylenia Aguilar  Central Arizona Water Conservation Dist.
#
#               party              funding      image  \
# 0        Republican  Traditional Funding  View Info
# 1        Democratic  Traditional Funding  View Info
# ...
